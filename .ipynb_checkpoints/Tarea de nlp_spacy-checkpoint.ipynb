# %% [markdown]
# # Pratica de nlp-spacy

# %% [markdown]
# ### cargar librerias

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import spacy
nlp = spacy.load("es_core_news_sm")
import re
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Subir mis datos

# %%
bbc_data = pd.read_csv("bbc_news.csv", sep=";")

# %%
bbc_data.head(5)
# Out:
#    Unnamed: 0  index                                              title  \
# 0           0   6684                         ¿Puedo negarme a trabajar?
# 1           1   9267  ¿Liz Truss, la candidata? El mundo reacciona a...
# 2           2   7387  El racionamiento de energía no es nada nuevo p...
# 3           3    767  La caza de superyates de oligarcas rusos sanci...
# 4           4   3712  Jubileo de Platino: 70 años de la Reina en 70 ...
#
#                          pubDate  \
# 0  Wed, 10 Aug 2022 15:46:18 GMT
# 1  Mon, 17 Oct 2022 11:35:12 GMT
# 2  Wed, 31 Aug 2022 05:20:18 GMT
# 3  Tue, 22 Mar 2022 14:37:01 GMT
# 4  Wed, 01 Jun 2022 23:17:33 GMT
#
#                                                 guid  \
# 0       https://www.bbc.co.uk/news/business-62147992
# 1          https://www.bbc.co.uk/news/world-63285480
# 2  https://www.bbc.co.uk/news/uk-scotland-highlan...
# 3                https://www.bbc.co.uk/news/60739336
# 4             https://www.bbc.co.uk/news/uk-61660128
#
#                                                 link  \
# 0  https://www.bbc.co.uk/news/business-62147992?a...
# 1  https://www.bbc.co.uk/news/world-63285480?at_m...
# 2  https://www.bbc.co.uk/news/uk-scotland-highlan...
# 3  https://www.bbc.co.uk/news/60739336?at_medium=...
# 4  https://www.bbc.co.uk/news/uk-61660128?at_medi...
#
#                                          description
# 0  With much of the UK enduring another period of...
# 1  The UK's political chaos has been watched arou...
# 2  Scoraig in the north west Highlands has long h...
# 3  Wealthy Russians sanctioned by the US, EU and ...
# 4  A quick look back at the Queen's 70 years on t...

# %%
bbc_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   1000 non-null   int64
#  1   index        1000 non-null   int64
#  2   title        1000 non-null   str
#  3   pubDate      999 non-null    str
#  4   guid         999 non-null    str
#  5   link         999 non-null    str
#  6   description  999 non-null    str
# dtypes: int64(2), str(5)
# memory usage: 54.8 KB

# %%
titles = pd.DataFrame(bbc_data['title'])
titles.head(5)
# Out:
#                                                title
# 0                         ¿Puedo negarme a trabajar?
# 1  ¿Liz Truss, la candidata? El mundo reacciona a...
# 2  El racionamiento de energía no es nada nuevo p...
# 3  La caza de superyates de oligarcas rusos sanci...
# 4  Jubileo de Platino: 70 años de la Reina en 70 ...

# %% [markdown]
# ## Limpiar los datos

# %%
titles['lowercase'] = titles['title'].str.lower()
titles.head()
# Out:
#                                                title  \
# 0                         ¿Puedo negarme a trabajar?
# 1  ¿Liz Truss, la candidata? El mundo reacciona a...
# 2  El racionamiento de energía no es nada nuevo p...
# 3  La caza de superyates de oligarcas rusos sanci...
# 4  Jubileo de Platino: 70 años de la Reina en 70 ...
#
#                                            lowercase
# 0                         ¿puedo negarme a trabajar?
# 1  ¿liz truss, la candidata? el mundo reacciona a...
# 2  el racionamiento de energía no es nada nuevo p...
# 3  la caza de superyates de oligarcas rusos sanci...
# 4  jubileo de platino: 70 años de la reina en 70 ...

# %%
en_stopwords = stopwords.words('spanish')
titles['no_stopwords'] = titles['lowercase'].apply(lambda x: ' '.join([word for word in x.split() if word not in (en_stopwords)]))
titles.head()
# Out:
#                                                title  \
# 0                         ¿Puedo negarme a trabajar?
# 1  ¿Liz Truss, la candidata? El mundo reacciona a...
# 2  El racionamiento de energía no es nada nuevo p...
# 3  La caza de superyates de oligarcas rusos sanci...
# 4  Jubileo de Platino: 70 años de la Reina en 70 ...
#
#                                            lowercase  \
# 0                         ¿puedo negarme a trabajar?
# 1  ¿liz truss, la candidata? el mundo reacciona a...
# 2  el racionamiento de energía no es nada nuevo p...
# 3  la caza de superyates de oligarcas rusos sanci...
# 4  jubileo de platino: 70 años de la reina en 70 ...
#
#                                         no_stopwords
# 0                           ¿puedo negarme trabajar?
# 1  ¿liz truss, candidata? mundo reacciona agitaci...
# 2        racionamiento energía nuevo comunidades red
# 3        caza superyates oligarcas rusos sancionados
# 4         jubileo platino: 70 años reina 70 segundos

# %%
titles['no_stopwords_no_punct'] = titles.apply(lambda x: re.sub(r"([^\w\s])", "", x['no_stopwords']), axis=1)
titles.head()
# Out:
#                                                title  \
# 0                         ¿Puedo negarme a trabajar?
# 1  ¿Liz Truss, la candidata? El mundo reacciona a...
# 2  El racionamiento de energía no es nada nuevo p...
# 3  La caza de superyates de oligarcas rusos sanci...
# 4  Jubileo de Platino: 70 años de la Reina en 70 ...
#
#                                            lowercase  \
# 0                         ¿puedo negarme a trabajar?
# 1  ¿liz truss, la candidata? el mundo reacciona a...
# 2  el racionamiento de energía no es nada nuevo p...
# 3  la caza de superyates de oligarcas rusos sanci...
# 4  jubileo de platino: 70 años de la reina en 70 ...
#
#                                         no_stopwords  \
# 0                           ¿puedo negarme trabajar?
# 1  ¿liz truss, candidata? mundo reacciona agitaci...
# 2        racionamiento energía nuevo comunidades red
# 3        caza superyates oligarcas rusos sancionados
# 4         jubileo platino: 70 años reina 70 segundos
#
#                                no_stopwords_no_punct  \
# 0                             puedo negarme trabajar
# 1  liz truss candidata mundo reacciona agitación ...
# 2        racionamiento energía nuevo comunidades red
# 3        caza superyates oligarcas rusos sancionados
# 4          jubileo platino 70 años reina 70 segundos
#
#                                           tokens_raw  \
# 0                  [¿Puedo, negarme, a, trabajar, ?]
# 1  [¿Liz, Truss, ,, la, candidata, ?, El, mundo, ...
# 2  [El, racionamiento, de, energía, no, es, nada,...
# 3  [La, caza, de, superyates, de, oligarcas, ruso...
# 4  [Jubileo, de, Platino, :, 70, años, de, la, Re...
#
#                                         tokens_clean  \
# 0                         [puedo, negarme, trabajar]
# 1  [liz, truss, candidata, mundo, reacciona, agit...
# 2  [racionamiento, energía, nuevo, comunidades, red]
# 3  [caza, superyates, oligarcas, rusos, sancionados]
# 4  [jubileo, platino, 70, años, reina, 70, segundos]
#
#                              tokens_clean_lemmatized
# 0                         [puedo, negarme, trabajar]
# 1  [liz, truss, candidata, mundo, reacciona, agit...
# 2  [racionamiento, energía, nuevo, comunidades, red]
# 3  [caza, superyates, oligarcas, rusos, sancionados]
# 4  [jubileo, platino, 70, años, reina, 70, segundos]

# %%
titles['tokens_raw'] = titles.apply(lambda x: word_tokenize(x['title']), axis=1)
titles['tokens_clean'] = titles.apply(lambda x: word_tokenize(x['no_stopwords_no_punct']), axis=1)
titles.head()
# Out:
#                                                title  \
# 0                         ¿Puedo negarme a trabajar?
# 1  ¿Liz Truss, la candidata? El mundo reacciona a...
# 2  El racionamiento de energía no es nada nuevo p...
# 3  La caza de superyates de oligarcas rusos sanci...
# 4  Jubileo de Platino: 70 años de la Reina en 70 ...
#
#                                            lowercase  \
# 0                         ¿puedo negarme a trabajar?
# 1  ¿liz truss, la candidata? el mundo reacciona a...
# 2  el racionamiento de energía no es nada nuevo p...
# 3  la caza de superyates de oligarcas rusos sanci...
# 4  jubileo de platino: 70 años de la reina en 70 ...
#
#                                         no_stopwords  \
# 0                           ¿puedo negarme trabajar?
# 1  ¿liz truss, candidata? mundo reacciona agitaci...
# 2        racionamiento energía nuevo comunidades red
# 3        caza superyates oligarcas rusos sancionados
# 4         jubileo platino: 70 años reina 70 segundos
#
#                                no_stopwords_no_punct  \
# 0                             puedo negarme trabajar
# 1  liz truss candidata mundo reacciona agitación ...
# 2        racionamiento energía nuevo comunidades red
# 3        caza superyates oligarcas rusos sancionados
# 4          jubileo platino 70 años reina 70 segundos
#
#                                           tokens_raw  \
# 0                  [¿Puedo, negarme, a, trabajar, ?]
# 1  [¿Liz, Truss, ,, la, candidata, ?, El, mundo, ...
# 2  [El, racionamiento, de, energía, no, es, nada,...
# 3  [La, caza, de, superyates, de, oligarcas, ruso...
# 4  [Jubileo, de, Platino, :, 70, años, de, la, Re...
#
#                                         tokens_clean
# 0                         [puedo, negarme, trabajar]
# 1  [liz, truss, candidata, mundo, reacciona, agit...
# 2  [racionamiento, energía, nuevo, comunidades, red]
# 3  [caza, superyates, oligarcas, rusos, sancionados]
# 4  [jubileo, platino, 70, años, reina, 70, segundos]

# %%
lemmatizer = WordNetLemmatizer()
titles["tokens_clean_lemmatized"] = titles["tokens_clean"].apply(lambda tokens: [lemmatizer.lemmatize(token) for token in tokens])
titles.head()
# Out:
#                                                title  \
# 0                         ¿Puedo negarme a trabajar?
# 1  ¿Liz Truss, la candidata? El mundo reacciona a...
# 2  El racionamiento de energía no es nada nuevo p...
# 3  La caza de superyates de oligarcas rusos sanci...
# 4  Jubileo de Platino: 70 años de la Reina en 70 ...
#
#                                            lowercase  \
# 0                         ¿puedo negarme a trabajar?
# 1  ¿liz truss, la candidata? el mundo reacciona a...
# 2  el racionamiento de energía no es nada nuevo p...
# 3  la caza de superyates de oligarcas rusos sanci...
# 4  jubileo de platino: 70 años de la reina en 70 ...
#
#                                         no_stopwords  \
# 0                           ¿puedo negarme trabajar?
# 1  ¿liz truss, candidata? mundo reacciona agitaci...
# 2        racionamiento energía nuevo comunidades red
# 3        caza superyates oligarcas rusos sancionados
# 4         jubileo platino: 70 años reina 70 segundos
#
#                                no_stopwords_no_punct  \
# 0                             puedo negarme trabajar
# 1  liz truss candidata mundo reacciona agitación ...
# 2        racionamiento energía nuevo comunidades red
# 3        caza superyates oligarcas rusos sancionados
# 4          jubileo platino 70 años reina 70 segundos
#
#                                           tokens_raw  \
# 0                  [¿Puedo, negarme, a, trabajar, ?]
# 1  [¿Liz, Truss, ,, la, candidata, ?, El, mundo, ...
# 2  [El, racionamiento, de, energía, no, es, nada,...
# 3  [La, caza, de, superyates, de, oligarcas, ruso...
# 4  [Jubileo, de, Platino, :, 70, años, de, la, Re...
#
#                                         tokens_clean  \
# 0                         [puedo, negarme, trabajar]
# 1  [liz, truss, candidata, mundo, reacciona, agit...
# 2  [racionamiento, energía, nuevo, comunidades, red]
# 3  [caza, superyates, oligarcas, rusos, sancionados]
# 4  [jubileo, platino, 70, años, reina, 70, segundos]
#
#                              tokens_clean_lemmatized
# 0                         [puedo, negarme, trabajar]
# 1  [liz, truss, candidata, mundo, reacciona, agit...
# 2  [racionamiento, energía, nuevo, comunidades, red]
# 3  [caza, superyates, oligarcas, rusos, sancionados]
# 4  [jubileo, platino, 70, años, reina, 70, segundos]

# %%
tokens_raw_list = sum(titles['tokens_raw'],  [])
tokens_clean_list = sum(titles['tokens_clean_lemmatized'], [])

# %% [markdown]
# ## Etiquetado POS

# %%
spacy_doc = nlp(' '.join(tokens_raw_list))

# %%
pos_df = pd.DataFrame(columns=['token', 'pos_tag'])

for token in spacy_doc:
    pos_df = pd.concat([pos_df,
                       pd.DataFrame.from_records([{'token': token.text,'pos_tag': token.pos_}])], ignore_index=True)

# %%
pos_df_counts = pos_df.groupby(['token','pos_tag']).size().reset_index(name='counts').sort_values(by='counts', ascending=False)
pos_df_counts.head(10)
# Out:
#      token pos_tag  counts
# 2402    de     ADP     945
# 101      :   PUNCT     554
# 3253    la     DET     431
# 2657    en     ADP     409
# 2624    el     DET     340
# 1687     a     ADP     259
# 4580     y   CCONJ     181
# 2436   del     ADP     179
# 3328   los     DET     174
# 17       ,   PUNCT     169

# %%
nouns = pos_df_counts[pos_df_counts.pos_tag == "NOUN"][0:10]
nouns
# Out:
#          token pos_tag  counts
# 1970      años    NOUN      32
# 4516      vida    NOUN      27
# 4515  victoria    NOUN      24
# 55        2022    NOUN      23
# 4152    semana    NOUN      14
# 9           ''    NOUN      13
# 3087    hombre    NOUN      13
# 2890     final    NOUN      13
# 3767   policía    NOUN      12
# 3019    guerra    NOUN      12

# %%
verbs = pos_df_counts[pos_df_counts.pos_tag == "VERB"][0:10]
verbs
# Out:
#         token pos_tag  counts
# 2526     dice    VERB      26
# 3033    hacer    VERB      10
# 2961     gana    VERB      10
# 1770   afirma    VERB       9
# 3372    marca    VERB       9
# 3473    muere    VERB       8
# 4036   retira    VERB       7
# 3846  promete    VERB       7
# 2745   espera    VERB       6
# 2392       da    VERB       6

# %%
adj = pos_df_counts[pos_df_counts.pos_tag == "ADJ"][0:10]
adj
# Out:
#         token pos_tag  counts
# 3820   primer     ADJ      19
# 3571    nuevo     ADJ      18
# 4083     ruso     ADJ      11
# 692      Gran     ADJ      11
# 3567    nueva     ADJ       9
# 8          ''     ADJ       9
# 4081     rusa     ADJ       8
# 4607   último     ADJ       7
# 3821  primera     ADJ       7
# 3408  mejores     ADJ       7

# %% [markdown]
# ## Abajo

# %%
ner_df = pd.DataFrame(columns=['token', 'ner_tag'])

for token in spacy_doc.ents:
    if pd.isna(token.label_) is False:
        ner_df = pd.concat([ner_df, pd.DataFrame.from_records(
            [{'token': token.text, 'ner_tag': token.label_}])], ignore_index=True)

# %%
ner_df.head()
# Out:
#                                                token ner_tag
# 0                                          Liz Truss     PER
# 1                                 El mundo reacciona    MISC
# 2                                     el Reino Unido     LOC
# 3                        El racionamiento de energía    MISC
# 4  La caza de superyates de oligarcas rusos sanci...    MISC

# %%
ner_df_counts = ner_df.groupby(['token','ner_tag']).size().reset_index(name='counts').sort_values(by='counts', ascending=False)
ner_df_counts.head(10)
# Out:
#                   token ner_tag  counts
# 523          Inglaterra     LOC      29
# 1215            Ucrania     LOC      21
# 1034        Reino Unido     LOC      16
# 220                Cómo     LOC      13
# 413             Francia     LOC      12
# 1332                  ¿     LOC      11
# 472   Guerra en Ucrania    MISC      11
# 1360               ¿Qué    MISC       9
# 1309     el Reino Unido     LOC       9
# 690           Liverpool     LOC       9

# %%
people = ner_df_counts[ner_df_counts.ner_tag == 'PER'][0:10]
people
# Out:
#                  token ner_tag  counts
# 1000             Putin     PER       8
# 90       Boris Johnson     PER       7
# 1031             Reina     PER       6
# 1045       Rishi Sunak     PER       5
# 696          Liz Truss     PER       5
# 591       Jürgen Klopp     PER       4
# 519       Indian Wells     PER       3
# 433   Gareth Southgate     PER       3
# 388            Everton     PER       3
# 40         Andy Murray     PER       3
